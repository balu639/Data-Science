# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
blood_sugars_men = [23,25,54,32,65,75,90,123,126,134]

blood_sugars_women = [24,12,45,63,72,34,90,120,154,132]

plt.hist([blood_sugars_men, blood_sugars_women],label=["men","women"], color = ['green', 'orange'])
plt.legend()
