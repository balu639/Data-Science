# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1,2,3,4,5,6,7]
y= [12,15,17,23,13,9,8]

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('WeatherData')
plt.plot(x,y, color ='green', linestyle='dotted', linewidth='3')

# %%
plt.plot(x,y,color='red', alpha=1.0)
