# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1,2,3,4,5,6,7]
y= [12,15,17,23,13,9,8]

# %%
plt.plot(x,y, 'g+-') #color is green, marker is + and the line

# %%
plt.plot(x,y,color = 'green',marker='+',linestyle='-') #same as above using parameters
